# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/hp/Desktop/DATA ANALYST/CASE STUDY/Dataset_for_data_cleaning_project.csv',index_col = "Id")
# there is index_col function using and  making "id " as index.
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df.to_string()
# Out:
# '        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice\n0        1          60       RL         65.0     8450   Pave   NaN      Reg         Lvl    AllP
# ...

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
df.columns # it returns column names
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.GrLivArea[0] # it shows indexing of some data from specific given column in square bracket
# Out:
# 1710

# %%
df["GrLivArea"] # it shows specific whole column data
# Out:
# 0       1710
# 1       1262
# 2       1786
# 3       1717
# 4       2198
#         ...
# 1455    1647
# 1456    2073
# 1457    2340
# 1458    1078
# 1459    1256
# Name: GrLivArea, Length: 1460, dtype: int64

# %%
x = { "sr.no" : [1,2,3,4], "name" : ["kishor","dolly","abhishek","kavitaben"]}
pd.DataFrame(x)
# Out:
# {'sr.no': [1, 2, 3, 4], 'name': ['kishor', 'dolly', 'abhishek', 'kavitaben']}

# %%
# it show specif row 
# eg
df.loc[2]
# Out:
# Id                    3
# MSSubClass           60
# MSZoning             RL
# LotFrontage        68.0
# LotArea           11250
#                   ...
# MoSold                9
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        223500
# Name: 2, Length: 81, dtype: object

# %%
df.loc[0:2] # slicing example
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %%
df.loc[[0,1,2]] # it shows first 3 rows when use list into list.
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %%
pd.set_option("display.max_rows", None) # it shows maximum rows
pd.set_option("display.max_column", None)
df.head() # its shows first 5 rows of the data , if you need more data you can do it by number in brackert().
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %%
df.tail() # it returns last 5 rows of dataframe.
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1456         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1457         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1458         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1459         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1460         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %%
df.info() # it returns information of dataframe like dtype,non-null value,column name its index and total columns and total rows.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df.shape # it retutns shape of dataframe in (row, column) format.
# Out:
# (1460, 80)

# %%
df.isnull().sum() # it returns total null values containing each columns.
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
''' if deletes the na values from dataframe by default axis = 0 means rows but when axis = 1 
it delete columns contain na values.''' 
new_df = df.dropna(axis = 1) 
new_df.shape
# Out:
# (1460, 61)

# %%
new_df.shape
# Out:
# (1460, 61)

# %%
new_df_2 = df.dropna()
new_df_2 # it returns no value just empty columns because all rows have atleast one null value.
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %%
df["LotFrontage"].fillna("bakvas",inplace = True )# we fill value instead of null value.

# %%
df["LotFrontage"].isnull().sum() # this shows null value is zero because we use inplace which update dataframe.
# Out:
# 0

# %%
x = df["GarageYrBlt"].mean() # we return mean value instead of null value.
df["GarageYrBlt"].fillna(x)
# Out:
# Id
# 1       2003.000000
# 2       1976.000000
# 3       2001.000000
# 4       1998.000000
# 5       2000.000000
# 6       1993.000000
# 7       2004.000000
# 8       1973.000000
# 9       1931.000000
# 10      1939.000000
# 11      1965.000000
# 12      2005.000000
# 13      1962.000000
# 14      2006.000000
# 15      1960.000000
# 16      1991.000000
# 17      1970.000000
# 18      1967.000000
# 19      2004.000000
# 20      1958.000000
# 21      2005.000000
# 22      1930.000000
# 23      2002.000000
# 24      1976.000000
# 25      1968.000000
# 26      2007.000000
# 27      2005.000000
# 28      2008.000000
# 29      1957.000000
# 30      1920.000000
# 31      1920.000000
# 32      1966.000000
# 33      2007.000000
# 34      1959.000000
# 35      2005.000000
# 36      2004.000000
# 37      1995.000000
# 38      1954.000000
# 39      1953.000000
# 40      1978.506164
# 41      1965.000000
# 42      1959.000000
# 43      1983.000000
# 44      1977.000000
# 45      1959.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   object
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df["YearBuilt"] = pd.to_datetime(df["YearBuilt"]) # We convert "YearBuilt"  column into datetime format.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   object
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df["SalePrice"] = pd.to_datetime(df["SalePrice"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   object
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df.head()
# Out:
#     MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL        65.0     8450   Pave   NaN      Reg
# 2           20       ms        80.0     9600   Pave   NaN      Reg
# 3           60       RL        68.0    11250   Pave   NaN      IR1
# 4           70       RL        60.0     9550   Pave   NaN      IR1
# 5           60       RL        84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# Id
# 1        Norm     1Fam     2Story            7            5
# ...

# %%
df.loc[2,"MSZoning"] = "ms" # replace false or errror values.
df.head()
# Out:
#     MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL        65.0     8450   Pave   NaN      Reg
# 2           20       ms        80.0     9600   Pave   NaN      Reg
# 3           60       RL        68.0    11250   Pave   NaN      IR1
# 4           70       RL        60.0     9550   Pave   NaN      IR1
# 5           60       RL        84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# Id
# 1        Norm     1Fam     2Story            7            5
# ...

# %%
# replace all false values by usinf for loop.

for x in df.index:
    if df.loc[x,"MSSubClass"] > 50:
        df.loc[x,"MSSubClass"] = 20
        
df.head()
# Out:
#     MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           20       RL        65.0     8450   Pave   NaN      Reg
# 2           20       ms        80.0     9600   Pave   NaN      Reg
# 3           20       RL        68.0    11250   Pave   NaN      IR1
# 4           20       RL        60.0     9550   Pave   NaN      IR1
# 5           20       RL        84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# Id
# 1        Norm     1Fam     2Story            7            5
# ...

# %%
new_df = df.drop_duplicates

# %%
df.corr()
# Out:
#                MSSubClass   LotArea  OverallQual  OverallCond  YearRemodAdd  \
# MSSubClass       1.000000 -0.021330    -0.230406     0.150557     -0.297137
# LotArea         -0.021330  1.000000     0.105806    -0.005636      0.013788
# OverallQual     -0.230406  0.105806     1.000000    -0.091932      0.550684
# OverallCond      0.150557 -0.005636    -0.091932     1.000000      0.073741
# YearRemodAdd    -0.297137  0.013788     0.550684     0.073741      1.000000
# MasVnrArea      -0.164401  0.104160     0.411876    -0.128101      0.179618
# BsmtFinSF1      -0.196134  0.214103     0.239666    -0.046231      0.128451
# BsmtFinSF2      -0.043430  0.111170    -0.059119     0.040229     -0.067759
# BsmtUnfSF        0.024149 -0.002618     0.308159    -0.136841      0.181133
# TotalBsmtSF     -0.195556  0.260833     0.537808    -0.171098      0.291066
# 1stFlrSF        -0.192349  0.299475     0.476224    -0.144203      0.240379
# ...
