# %%
exp =[2200,2350,2600,2130,2190]
extra_spent_in_feb = exp[1]-exp[0]
print(extra_spent_in_feb)
# Out:
# 150

# %%
total_exp_in_first_quater = exp[0]+exp[1]+exp[2]
print(total_exp_in_first_quater)
# Out:
# 7150

# %%
print(2000 in exp)
# Out:
# False

# %%
exp.append(1980)
print(exp)
# Out:
# [2200, 2350, 2600, 2130, 2190, 1980]

# %%
exp[3] = exp[3]-200
print(exp)
# Out:
# [2200, 2350, 2600, 1930, 2190, 1980]

# %%
heros=['spider man','thor','hulk','iron man','captain america']
len(heros)
# Out:
# 5

# %%
heros.append("black panther")
print(heros)
# Out:
# ['spider man', 'thor', 'hulk', 'iron man', 'captain america', 'black panther']

# %%
heros.remove("black panther")
heros.insert(3,"black panther")
print(heros)
# Out:
# ['spider man', 'thor', 'hulk', 'black panther', 'iron man', 'captain america']

# %%
heros[1:3]=["doctor strange"]
print(heros)
# Out:
# ['spider man', 'doctor strange', 'black panther', 'iron man', 'captain america']

# %%
dir(heros)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
heros.sort()
print(heros)
# Out:
# ['black panther', 'captain america', 'doctor strange', 'iron man', 'spider man']

# %%
india = ["mumbai","banglore","chennai","delhi"]
pakistan = ["lahore","karachi","islamabad"]
bangladesh = ["dhaka","khulna","rangpur"]

city_name = input("enter your city name :")
if city_name in india :
    print("your country is india")
elif city_name in pakistan:
    print("your country is pakistan")
elif city_name in bangladesh:
    print("your country is bangladesh")
else:
    print("your country is not in list")
# Out:
# enter your city name :
#   @media print {
#     .ms-editor-squiggles-container {
#       display:none !important;
#     }
#   }
#   .ms-editor-squiggles-container {
#     all: initial;
#   }delhi
# your country is india

# %%
india = ["mumbai","banglore","chennai","delhi"]
pakistan = ["lahore","karachi","islamabad"]
bangladesh = ["dhaka","khulna","rangpur"]

city_name_1 = input("enter your city name :")
city_name_2 = input("enter your city name :")
if city_name_1 and city_name_2 in india :
    print("your country is india")
elif city_name_1 and city_name_2 in pakistan:
    print("your country is pakistan")
elif city_name_1 and city_name_2 in bangladesh:
    print("your country is bangladesh")
else:
    print("your country is not in list")
# Out:
# enter your city name :delhi
# enter your city name :banglore
# your country is india

# %%
sugar_level = input("enter your fasting sugar level :")
sugar_level = float(sugar_level)
if sugar_level<80:
    print("your sugar level is low")
elif sugar_level>100:
    print("sugar level is high")
else :
    print("sugar level is normal")
# Out:
# enter your fasting sugar level :80
# sugar level is normal

# %%
result = ["heads","tails","tails","heads","tails","heads","heads","tails","tails","tails"]

count = 0

for i in result:
    if i == "heads":
        count= count + 1
    
print("total heads count is :",count)
# Out:
# total heads count is : 4

# %%
for i in range(11):
    if i%2==0:
        continue
    print(i*i)
# Out:
# 1
# 9
# 25
# 49
# 81

# %%
month_list = ["january","february","march","april","may"]
expense_list = [2340, 2500, 2100, 3100, 2980]
e = input("enter your expense amount:")
e = int(e)

month = -1
for i in range(len(expense_list)):
    if e == expense_list[i]:
        month = i
        break
if month != -1:
    print(f"your spent {e} in {month_list[month]}")
else :
    print(f"you didn't spent {e} in any month")
# Out:
# enter your expense amount:2500
# your spent 2500 in february

# %%
for i in range(5):
    print(f" you completed {i+1} miles ")
    tired = input("are you tired: ")
    if tired == "yes":
        break
if i == 4:
    print(" congrats! you completed race")
else:
    print(f"you completed {i+1} miles, but you don't completed race")
# Out:
#  you completed 1 miles
# are you tired: no
#  you completed 2 miles
# are you tired: no
#  you completed 3 miles
# are you tired: no
#  you completed 4 miles
# are you tired: no
#  you completed 5 miles
# are you tired: no
#  congrats! you completed race

# %%
def total_function(exp):
    total = 0
    for i in exp:
        total = i + total
    return print("total is ",total)
    
bharat_total_expenses =[10,20,30,40,50]
total_function(bharat_total_expenses)
# Out:
# total is  150

# %%
def area(r,h,shape):
    if r>0 and h>0 and shape == "triangle":
        area_triangle = (1/3)*(2*r)*h
        return print("Area of triangle is ",area_triangle)
    else:
        area_rectangle = r * h
        return print("area of rectangle is ",area_rectangle)
    
r = int(input("write dimension_1:"))
h = int(input("write dimension_2:"))
shape =input("write shape:")
area(r,h,shape)
# Out:
# write dimension_1:5
# write dimension_2:5
# write shape:triangle
# Area of triangle is  16.666666666666664

# %%
for i in range(6):
        s = ''
        for j in range(i+1):
            s = s + '*'
        print(s)
# Out:
# *
# **
# ***
# ****
# *****
# ******

# %%
def diagram(n):
    for i in range(n):
        s = ''
        for j in range(i+1):
            s = s +'*'
        print(s)
    
n=int(input("write your fav number " ))
diagram(n)
# Out:
# write your fav number 5
# *
# **
# ***
# ****
# *****

# %%
for i in range(6):
    s = ' '
    for j in range (i+1):
        s = s + '*'
    print(s)
# Out:
#  *
#  **
#  ***
#  ****
#  *****
#  ******

# %%
population = {"china" :143, "india": 136, "usa":32 ,"pakistan":21 }

def add():
    country = input("enter country name to add:")
    country = country.lower()
    if country in population:
        print("country already exist in our dataset, terminating")
        return
        p = input(f"enter population for {country}")
        p = float(p)
        population[country] = p
        print_all()
         
def remove():
    country = input("enter country name to remove")
    country = country.lower()
    if country not in population:
        print("country doesn't exist in dataset,terminating")
    return
    del population[country]
    print_all()
    

def query():
    country = input("enter country name to query")
    country = country.lower()
    if country not in population:
        print("country doesn't exist in dataset,terminating")
        return
        print(f"population of {country} is {population[country]} crore")
    
def print_all():
    for country,p in population.items:
        print(f" {country} ==> {p}")
              
def main():
    op = input("enter operation (print,add,remove,query) :")
    if op.lower == "print":
        print_all()
    elif op.lower =="add":
        add()
    elif op.lower == "remove":
        remove()
    elif op.lower == "query":
        query()
        
if __name__ == "__main__":
    main()
# Out:
# enter operation (print,add,remove,query) :add

# %%
population = {
    'china': 143,
    'india': 136,
    'usa': 32,
    'pakistan': 21
}

def add():
    country=input("Enter country name to add:")
    country=country.lower()
    if country in population:
        print("Country already exist in our dataset. Terminating")
        return
    p=input(f"Enter population for {country}")
    p=float(p)
    population[country]=p # Adds new key value pair to dictionary
    print_all()

def remove():
    country = input("Enter country name to remove:")
    country = country.lower()
    if country not in population:
        print("Country doesn't exist in our dataset. Terminating")
        return
    del population[country]
    print_all()

def query():
    country = input("Enter country name to query:")
    country = country.lower()
    if country not in population:
        print("Country doesn't exist in our dataset. Terminating")
        return
    print(f"Population of {country} is: {population[country]} crore")

def print_all():
    for country, p in population.items():
        print(f"{country}==>{p}")

def main():
    op=input("Enter operation (add, remove, query or print):")
    if op.lower() == 'add':
        add()
    elif op.lower() == 'remove':
        remove()
    elif op.lower() == 'query':
        query()
    elif op.lower() == 'print':
        print_all()

if __name__ == '__main__':
    main()
# Out:
# Enter operation (add, remove, query or print):add
# Enter country name to add:australia
# Enter population for australia32
# china==>143
# india==>136
# usa==>32
# pakistan==>21
# australia==>32.0

# %%
pip install jupyterthemes
# Out:
# ...
#
# ...

# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t onedork

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/hp/Desktop/DATA ANALYST/bellabeat_data/dailyActivity_merged.csv")

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
p= (1,2,3)
print(p)
# Out:
# (1, 2, 3)

# %%
p= (1,2,3)
print(p)
# Out:
# (1, 2, 3)
